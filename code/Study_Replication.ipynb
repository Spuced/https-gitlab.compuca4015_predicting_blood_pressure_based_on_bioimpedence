# %% [markdown]
# ## **Study Replication**

# %% [markdown]
# In this notebook I am going to train and AdaBoost model on their features.
#
# In their approach each subject has a bespoke model, trained only on their data.
#
# Their features and code can be found [here](https://github.com/TAMU-ESP/Graphene_BP/tree/main).

# %%
import pandas as pd

# %% [markdown]
# ##### I am going to replicate the default version of their code.
# This uses f2_ma10_mn1_cn1_all.csv.

# %% [markdown]
# Load the datasets.

# %%
df = pd.read_csv("../../data/Graphene_BP-Data-features/2020-11-05/f2_ma10_mn1_cn1_all.csv")
df
# Out:
#        Sample  subject_id  setup_n  trial_n    fc   B1_MS__T   B2_MS__T  \
# 0           1           1        1        1  9375   1.362176   1.360896
# 1           2           1        1        1  9375   2.039125   2.038059
# 2           3           1        1        1  9375   2.698155   2.696491
# 3           4           1        1        1  9375   3.346560   3.344512
# 4           5           1        1        1  9375   3.966464   3.965227
# ...       ...         ...      ...      ...   ...        ...        ...
# 29804    1992           1        3       14  9375  84.028971  84.031616
# 29805    1993           1        3       14  9375  84.642219  84.637995
# 29806    1994           1        3       14  9375  85.283584  85.280512
# 29807    1995           1        3       14  9375  85.918933  85.914752
# 29808    1996           1        3       14  9375  86.541312  86.539307
#
#         B3_MS__T   B4_MS__T  PPG_MS__T  ...  P_D2D__IPA  P_D2M__IPAR  \
# 0       1.350357   1.374123   1.400405  ...   21.125804     0.075600
# 1       2.022869  44.407641   2.075989  ...   22.057734     0.074614
# 2       2.683776   2.692992   2.734208  ...   22.677360     0.073067
# 3       3.336363   3.336192   3.381205  ...   19.052404     0.079666
# 4       3.948117  44.407641   4.001707  ...   20.579856     0.077619
# ...          ...        ...        ...  ...         ...          ...
# 29804  84.012544  48.203017  84.071253  ...   12.323505     0.128618
# 29805  84.635691  48.203017  84.685312  ...    9.000323     0.118125
# 29806  42.889860  85.273728  85.323989  ...   15.393642     0.203967
# 29807  42.889860  48.203017  85.962283  ...   12.130614     0.186940
# 29808  42.889860  48.203017  86.582485  ...   12.328871     0.147680
#
#        P_D2S__IPAR  P_D2I__IPAR        DBP         SBP        setup_name  \
# 0         0.350191     0.964550  77.150605  120.531853  setup01_baseline
# 1         0.346211     0.955513  76.467119  121.353248  setup01_baseline
# 2         0.336330     0.941976  76.822703  122.553652  setup01_baseline
# 3         0.362136     0.994654  77.719712  120.973820  setup01_baseline
# 4         0.353275     0.935495  78.902194  120.850108  setup01_baseline
# ...            ...          ...        ...         ...               ...
# 29804     0.407596     0.978555  78.578980  126.779706  setup03_valsalva
# 29805     0.453181     0.950402  76.598455  127.226945  setup03_valsalva
# 29806     0.447446     0.949446  74.924877  123.889615  setup03_valsalva
# 29807     0.460745     0.964781  74.088953  121.692170  setup03_valsalva
# 29808     0.414923     0.932143  73.632324  121.984657  setup03_valsalva
#
#             exp_name  Sample_c                  exp_setup_name
# 0      subject1_day1         1  subject1_day1_setup01_baseline
# 1      subject1_day1         2  subject1_day1_setup01_baseline
# 2      subject1_day1         3  subject1_day1_setup01_baseline
# 3      subject1_day1         4  subject1_day1_setup01_baseline
# 4      subject1_day1         5  subject1_day1_setup01_baseline
# ...              ...       ...                             ...
# 29804  subject1_day4      7822  subject1_day4_setup03_valsalva
# 29805  subject1_day4      7823  subject1_day4_setup03_valsalva
# 29806  subject1_day4      7824  subject1_day4_setup03_valsalva
# 29807  subject1_day4      7825  subject1_day4_setup03_valsalva
# 29808  subject1_day4      7826  subject1_day4_setup03_valsalva
#
# [29809 rows x 89 columns]

# %% [markdown]
# They actually leave out subject 7.

# %%
print(df['subject_id'].unique())
# Out:
# [1 2 3 4 5 6]
